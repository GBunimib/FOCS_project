# %%
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date 
import random

# %% [markdown]
# **1. Normalize the loan_lenders table. In the normalized table, each row must have one loan_id and one lender.**

# %%
loans_lenders = pd.read_csv("C:/Users/giuli/Google Drive/DS/Foundation of computer science/Progetto/loans_lenders.csv")
loans_lenders.head()
# Out:
#    loan_id                                            lenders
# 0   483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1   483738  muc888, nora3555, williammanashi, barbara5610,...
# 2   485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3   486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4   534428  muc888, niki3008, teresa9174, mike4896, david7...

# %%
#Lista contenente la lista di prestatori che partecipano ad ogni prestito
liste = [loans_lenders.lenders[i].split(',') for i in range(len(loans_lenders))]

#Lista unica contentente tutti i prestatori
lista = [item for elem in liste for item in elem]

# %%
#Dataframe contenente i prestatori

Lender = pd.DataFrame(lista, columns = ['permanent_name']) 
Lender.head()
# Out:
#   permanent_name
# 0         muc888
# 1        sam4326
# 2    camaran3922
# 3    lachheb1865
# 4    rebecca3499

# %%
#Conteggio di quanti prestatori partecipano ad ogni prestitio (loan_id)
lunghezze = [len(elem) for elem in liste]   

#Replica il numero id del prestito tante volte quanti sono i prestatori che vi partecipano
rep = np.repeat(loans_lenders.loan_id, lunghezze)

# %%
#Dataframe che contiene le ripetizioni degli id per numero di lender

rep_id = pd.DataFrame(rep).reset_index() 
rep_id = rep_id.drop('index', 1)
rep_id.head()
# Out:
#    loan_id
# 0   483693
# 1   483693
# 2   483693
# 3   483693
# 4   483693

# %%
#Unisce le due liste così da ottenere un id del prestito per ogni prestatore che vi partecipa

loan_lender = pd.concat([rep_id, Lender], axis = 1)
loan_lender.head()
# Out:
#    loan_id permanent_name
# 0   483693         muc888
# 1   483693        sam4326
# 2   483693    camaran3922
# 3   483693    lachheb1865
# 4   483693    rebecca3499

# %% [markdown]
# **2. For each loan, add a column duration corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.**

# %%
loans = pd.read_csv("C:/Users/giuli/Google Drive/DS/Foundation of computer science/Progetto/loans.csv",
                 parse_dates = ['disburse_time', 'planned_expiration_time'] ) 
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# ...

# %%
#Differenza tra le colonne interessate ed estrae il valore giorno, i valori nulli sono sostituiti con 0

loans['duration'] = (loans['planned_expiration_time'] - loans['disburse_time']).apply(lambda x: x.days).fillna(0)
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# ...

# %% [markdown]
# **3. Find the lenders that have funded at least twice.**

# %%
#Conta quante volte un prestatore ha partecipato ai prestiti

lender = pd.DataFrame(loan_lender.groupby('permanent_name').count()['loan_id']) 
lender = lender.rename(columns = {'loan_id':'count_lender'})
lender.head()
# Out:
#                  count_lender
# permanent_name
#  000                       39
#  00000                     39
#  0002                      70
#  00mike00                   1
#  0101craign0101            71

# %%
#Perstatori che hanno prestato più di una volta

good_lender = lender[lender['count_lender'] > 1] 
good_lender.head()
# Out:
#                  count_lender
# permanent_name
#  000                       39
#  00000                     39
#  0002                      70
#  0101craign0101            71
#  0132575                    4

# %% [markdown]
# **4. For each country, compute how many loans have involved that country as borrowers**

# %%
#Conta il numero di prestiti per stato

country_loans = pd.DataFrame(loans.groupby(['country_name']).count()['loan_id']) 
country_loans = country_loans.rename(columns = {'loan_id':'count_loans'})
country_loans.head()
# Out:
#               count_loans
# country_name
# Afghanistan          2337
# Albania              3075
# Armenia             13952
# Azerbaijan          10172
# Belize                218

# %% [markdown]
# **5. For each country, compute the overall amount of money borrowed.**

# %%
#Somma dell'importo prestato ad ogni stato

country_amount = pd.DataFrame(loans.groupby(['country_code']).sum()['funded_amount']) 
country_amount = country_amount.rename(columns = {'funded_amount':'funded_country'})
country_amount.head()
# Out:
#               funded_country
# country_code
# AF                 1964650.0
# AL                 3992475.0
# AM                20284675.0
# AZ                14191350.0
# BA                  477250.0

# %% [markdown]
# **6. Like the previous point, but expressed as a percentage of the overall amount lent**

# %%
#Totale importo prestato

total_lent = country_amount.sum(axis = 0)['funded_country'] 
total_lent
# Out:
# 1130145645.0

# %%
#Calcola il valore percentuale: totale prestato ad ogni stato / totale complessivo prestato * 100

country_amount['funded_country%'] = country_amount['funded_country'] / total_lent * 100  
country_amount.head()
# Out:
#               funded_country  funded_country%
# country_code
# AF                 1964650.0         0.173840
# AL                 3992475.0         0.353271
# AM                20284675.0         1.794873
# AZ                14191350.0         1.255710
# BA                  477250.0         0.042229

# %% [markdown]
# **7. Like the three previous points, but split for each year (with respect to disburse time)**

# %%
#Estrae l'anno di pagamento

loans['disburse_year'] = loans.disburse_time.dt.year.astype('Int64')
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# ...

# %% [markdown]
# 7.1. For each country, compute how many loans have involved that country as borrowers, split for each year

# %%
#Conta il numero di prestiti ad ogni stato diviso per anno

state_year_loans = pd.DataFrame(loans.groupby(['country_name', 'disburse_year']).count()['loan_id']) 
state_year_loans = state_year_loans.rename(columns = {'loan_id':'count_loans'})
state_year_loans.head()
# Out:
#                             count_loans
# country_name disburse_year
# Afghanistan  2007                   408
#              2008                   370
#              2009                   678
#              2010                   632
#              2011                   247

# %% [markdown]
# 7.2. For each country and year, compute the overall amount of money borrowed.

# %%
#Somma per stato e anno dell'importo preso in prestito

state_year_amount = pd.DataFrame(loans.groupby(['country_name', 'disburse_year']).sum()['funded_amount']) 
state_year_amount = state_year_amount.rename(columns = {'funded_amount':'funded_country_year'})
state_year_amount.head()
# Out:
#                             funded_country_year
# country_name disburse_year
# Afghanistan  2007                      194975.0
#              2008                      365375.0
#              2009                      581825.0
#              2010                      563350.0
#              2011                      245125.0

# %% [markdown]
# 7.3. Like the previous point, but expressed as a percentage of the overall amount lent in the year

# %%
#Totale preso in prestito per anno

total_lent_year = pd.DataFrame(loans.groupby('disburse_year').sum()['funded_amount']) 
total_lent_year = total_lent_year.rename(columns={'funded_amount':'funded_year'})
total_lent_year
# Out:
#                funded_year
# disburse_year
# 2005              102850.0
# 2006             1375175.0
# 2007            15439425.0
# 2008            39384425.0
# 2009            59477925.0
# 2010            72187300.0
# 2011            93601250.0
# 2012           115427450.0
# 2013           128301200.0
# 2014           146668375.0
# 2015           148808700.0
# 2016           151001875.0
# 2017           155644275.0
# 2018              771550.0

# %%
#Calcola il valore percentuale: importo prestato allo stato nell'anno / totale complessivo per anno * 100

state_year_amount['funded%'] = state_year_amount['funded_country_year'] / total_lent_year['funded_year'] * 100 
state_year_amount.head()
# Out:
#                             funded_country_year   funded%
# country_name disburse_year
# Afghanistan  2007                      194975.0  1.262838
#              2008                      365375.0  0.927714
#              2009                      581825.0  0.978220
#              2010                      563350.0  0.780400
#              2011                      245125.0  0.261882

# %% [markdown]
# **8. For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.**

# %%
#Divide equamente l'importo prestato per il numero di persone che partecipano al prestito

loans['amount_lender'] = loans['funded_amount'] / loans['num_lenders_total']
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# ...

# %%
#Estrae da loans solo le colonne di interesse per velocizzare il procedimento

small_loans = loans[['loan_id', 'amount_lender']].copy()
small_loans.head()
# Out:
#    loan_id  amount_lender
# 0   657307      41.666667
# 1   657259      36.363636
# 2   658010      25.000000
# 3   659347      29.761905
# 4   656933      28.333333

# %%
#Unisce il dataset creato sopra con loan_lender (contenete il codice del prestito a cui ha partecipato ogni prestatore) su loan_id

merged = pd.merge(small_loans, loan_lender, on = 'loan_id')
merged.head()
# Out:
#    loan_id  amount_lender  permanent_name
# 0   657307      41.666667     spencer5657
# 1   657307      41.666667     matthew8640
# 2   657307      41.666667   larry71496105
# 3   657259      36.363636             ltr
# 4   657259      36.363636      andrew5306

# %%
#Somma il totale prestato per ogni prestatore

lender_lent = pd.DataFrame(merged.groupby('permanent_name').sum()['amount_lender'])
lender_lent.head()
# Out:
#                  amount_lender
# permanent_name
#  000               1485.309656
#  00000             1249.127691
#  0002              2201.180463
#  00mike00            38.461538
#  0101craign0101    2424.088932

# %% [markdown]
# **9. For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.**

# %%
lenders = pd.read_csv('C:/Users/giuli/Google Drive/DS/Foundation of computer science/Progetto/lenders.csv')
lenders.head()
# Out:
#    permanent_name display_name city state country_code  member_since  \
# 0        qian3013         Qian  NaN   NaN          NaN    1461300457
# 1       reena6733        Reena  NaN   NaN          NaN    1461300634
# 2         mai5982          Mai  NaN   NaN          NaN    1461300853
# 3  andrew86079135       Andrew  NaN   NaN          NaN    1461301091
# 4      nguyen6962       Nguyen  NaN   NaN          NaN    1461301154
#
#   occupation loan_because  loan_purchase_num invited_by  num_invited
# 0        NaN          NaN                1.0        NaN            0
# 1        NaN          NaN                9.0        NaN            0
# 2        NaN          NaN                NaN        NaN            0
# 3        NaN          NaN                5.0  Peter Tan            0
# 4        NaN          NaN                NaN        NaN            0

# %%
#Lista contenente gli stati non nulli

country = list(lenders['country_code'].dropna())

# %%
#Creazione di un dizionario in cui, ad ogni stato, è associata la percentuale con la quale si presenta all'interno di lenders

proporzioni = {}
for stato in country:
  if stato not in proporzioni:
    proporzioni[stato] = country.count(stato) / len(country) * 100

# %% [markdown]
# Output proporzioni
#
# {'US': 66.43302539248702,
#  'IN': 0.8088359970759282,
#  'AU': 4.166353186104145,
#  'PL': 0.26994887365966,
#  'BR': 0.4716244880909202,
#  'CN': 0.14261026187511158,
#  'FR': 0.8162472390316425,
#  'BG': 0.05928993564571569,...}

# %%
#Sostituisce ai valori NA di country_code uno stato (chiave) scelto dal dizionario proporzioni,
#proporzionalmente alla frequenza (valore) con cui si presenta

lenders["country_code"].fillna(random.choices(list(proporzioni.keys()), weights = list(proporzioni.values()), k = 1)[0], inplace = True) 
lenders.head()
# Out:
#    permanent_name display_name city state country_code  member_since  \
# 0        qian3013         Qian  NaN   NaN           NZ    1461300457
# 1       reena6733        Reena  NaN   NaN           NZ    1461300634
# 2         mai5982          Mai  NaN   NaN           NZ    1461300853
# 3  andrew86079135       Andrew  NaN   NaN           NZ    1461301091
# 4      nguyen6962       Nguyen  NaN   NaN           NZ    1461301154
#
#   occupation loan_because  loan_purchase_num invited_by  num_invited
# 0        NaN          NaN                1.0        NaN            0
# 1        NaN          NaN                9.0        NaN            0
# 2        NaN          NaN                NaN        NaN            0
# 3        NaN          NaN                5.0  Peter Tan            0
# 4        NaN          NaN                NaN        NaN            0

# %%
#Estrae colonne di interesse da lenders per velocizzare il procedimento

small_lenders = lenders[['permanent_name', 'country_code']].copy()
small_lenders.head()
# Out:
#    permanent_name country_code
# 0        qian3013           NZ
# 1       reena6733           NZ
# 2         mai5982           NZ
# 3  andrew86079135           NZ
# 4      nguyen6962           NZ

# %%
#Unisce il dataset creato sopra con lender_lent (conentente il quantitativo prestato da ogni prestatore) su permanent_name

merged1 = pd.merge(small_lenders, lender_lent, on = 'permanent_name')
merged1.head()
# Out:
#         permanent_name country_code  amount_lender
# 0           naresh2074           US      58.820663
# 1          jinxian2217           NZ      45.161290
# 2         sreedevi9583           NZ      25.000000
# 3       nicole98153893           NZ      28.571429
# 4  prashankpradeep8456           US      25.000000

# %%
#Somma per stato di quanto è stato prestato

tot_lent_country = pd.DataFrame(merged1.groupby('country_code').sum())
tot_lent_country = tot_lent_country.rename(columns={'amount_lender':'lent_country'})
tot_lent_country.head()
# Out:
#               lent_country
# country_code
# AD              101.190476
# AE            93008.082820
# AF             4518.672455
# AL              627.252119
# AM              571.253355

# %%
#Unisce il dataset sopra con country_amount (contentente l'importo prestato ad ogni stato) su country_code

country_diff = pd.merge(tot_lent_country, country_amount, on = 'country_code')
country_diff.head()
# Out:
#               lent_country  funded_country  funded_country%
# country_code
# AF             4518.672455       1964650.0         0.173840
# AL              627.252119       3992475.0         0.353271
# AM              571.253355      20284675.0         1.794873
# AZ              142.883491      14191350.0         1.255710
# BA             3412.307840        477250.0         0.042229

# %%
#Calcola la differenza tra quanto è stato prestato da ogni stato e quanto è stato preso in prestito

country_diff['difference'] = country_diff['lent_country'] - country_diff['funded_country']
country_diff.head()
# Out:
#               lent_country  funded_country  funded_country%    difference
# country_code
# AF             4518.672455       1964650.0         0.173840 -1.960131e+06
# AL              627.252119       3992475.0         0.353271 -3.991848e+06
# AM              571.253355      20284675.0         1.794873 -2.028410e+07
# AZ              142.883491      14191350.0         1.255710 -1.419121e+07
# BA             3412.307840        477250.0         0.042229 -4.738377e+05

# %% [markdown]
# **10. Which country has the highest ratio between the difference computed at the previous point and the population?**

# %%
country_stats = pd.read_csv("C:/Users/giuli/Google Drive/DS/Foundation of computer science/Progetto/country_stats.csv") 
country_stats.head()
# Out:
#   country_name country_code country_code3 continent           region  \
# 0        India           IN           IND      Asia    Southern Asia
# 1      Nigeria           NG           NGA    Africa   Western Africa
# 2       Mexico           MX           MEX  Americas  Central America
# 3     Pakistan           PK           PAK      Asia    Southern Asia
# 4   Bangladesh           BD           BGD      Asia    Southern Asia
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0  1339180127                           21.9  0.623559           68.322
# 1   190886311                           70.0  0.527105           53.057
# 2   129163276                           46.2  0.761683           76.972
# 3   197015955                           29.5  0.550354           66.365
# 4   164669751                           31.5  0.578824           71.985
#
#    expected_years_of_schooling  mean_years_of_schooling           gni  \
# ...

# %%
#Unisce country_stats con country_diff (contenente le differenze tra ciò che è stato prestato da ogni stato e quanto è stato preso in prestito)

merged2 = pd.merge(country_stats, country_diff, on = 'country_code')
merged2.head()
# Out:
#     country_name country_code country_code3 continent            region  \
# 0          India           IN           IND      Asia     Southern Asia
# 1        Nigeria           NG           NGA    Africa    Western Africa
# 2         Mexico           MX           MEX  Americas   Central America
# 3       Pakistan           PK           PAK      Asia     Southern Asia
# 4  United States           US           USA  Americas  Northern America
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0  1339180127                           21.9  0.623559           68.322
# 1   190886311                           70.0  0.527105           53.057
# 2   129163276                           46.2  0.761683           76.972
# 3   197015955                           29.5  0.550354           66.365
# 4   324459463                           15.1  0.919553           79.222
#
#    expected_years_of_schooling  mean_years_of_schooling           gni  \
# ...

# %%
#Calcola il rapporto tra la differenza e la popolazione di ogni stato

merged2['ratio'] = abs(merged2['difference'] / merged2['population'])
merged2.head()
# Out:
#     country_name country_code country_code3 continent            region  \
# 0          India           IN           IND      Asia     Southern Asia
# 1        Nigeria           NG           NGA    Africa    Western Africa
# 2         Mexico           MX           MEX  Americas   Central America
# 3       Pakistan           PK           PAK      Asia     Southern Asia
# 4  United States           US           USA  Americas  Northern America
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0  1339180127                           21.9  0.623559           68.322
# 1   190886311                           70.0  0.527105           53.057
# 2   129163276                           46.2  0.761683           76.972
# 3   197015955                           29.5  0.550354           66.365
# 4   324459463                           15.1  0.919553           79.222
#
#    expected_years_of_schooling  mean_years_of_schooling           gni  \
# ...

# %%
dif_on_pop = merged2[['country_name','country_code', 'population', 'difference', 'ratio']].copy()
dif_on_pop.sort_values(by = 'ratio', ascending = False).head()

#Il Paraguay ha il più alto rapporto tra la differenza e la popolazione
# Out:
#    country_name country_code  population    difference     ratio
# 57     Paraguay           PY     6811297 -5.371445e+07  7.886083
# 64      Armenia           AM     2930450 -2.028410e+07  6.921839
# 51  El Salvador           SV     6377853 -3.787998e+07  5.939299
# 66     Mongolia           MN     3075647 -1.489200e+07  4.841909
# 53    Nicaragua           NI     6217581 -2.903952e+07  4.670550

# %% [markdown]
# **11. Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?**

# %%
#Calcola la popolazione sotto la linea di povertà

merged2['pop_below_pline'] = merged2['population'] * merged2['population_below_poverty_line'] / 100

# %%
#Calcola il rapporto tra la differenza e la quantità di popolazione sotto la linea di povertà

merged2['ratio_pline'] = abs(merged2['difference'] / merged2['pop_below_pline'])
merged2.head()
# Out:
#     country_name country_code country_code3 continent            region  \
# 0          India           IN           IND      Asia     Southern Asia
# 1        Nigeria           NG           NGA    Africa    Western Africa
# 2         Mexico           MX           MEX  Americas   Central America
# 3       Pakistan           PK           PAK      Asia     Southern Asia
# 4  United States           US           USA  Americas  Northern America
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0  1339180127                           21.9  0.623559           68.322
# 1   190886311                           70.0  0.527105           53.057
# 2   129163276                           46.2  0.761683           76.972
# 3   197015955                           29.5  0.550354           66.365
# 4   324459463                           15.1  0.919553           79.222
#
#    expected_years_of_schooling  mean_years_of_schooling           gni  \
# ...

# %%
dif_on_Ppop = merged2[['country_name', 'country_code','population', 'population_below_poverty_line', 'difference', 'ratio_pline']].copy()
dif_on_Ppop.sort_values(by = 'ratio_pline', ascending = False) 

#Il Paraguay ha il maggior tasso di poveri rispetto alla differenza
# Out:
#         country_name country_code  population  population_below_poverty_line  \
# 57          Paraguay           PY     6811297                           22.2
# 69        Azerbaijan           AZ     9827589                            4.9
# 72           Georgia           GE     3912061                            9.2
# 66          Mongolia           MN     3075647                           21.6
# 64           Armenia           AM     2930450                           32.0
# ..               ...          ...         ...                            ...
# 73           Uruguay           UY     3456750                            9.7
# 44  Papua New Guinea           PG     8251162                           37.0
# 5              China           CN  1409517397                            3.3
# 76       Puerto Rico           PR     3663131                            NaN
# 77         Palestine           PS     4920724                            NaN
#
#       difference  ratio_pline
# ...

# %% [markdown]
# **12. For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD * 31 / (31+365+30) = 363.85 for 2016, 5000USD * 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.**

# %%
#Estrae da loans le colonne di interesse per velocizzare il procedimento

ridotto=loans[['loan_id','disburse_time', 'planned_expiration_time', 'loan_amount', 'duration', 'disburse_year']].copy()
ridotto.head()
# Out:
#    loan_id             disburse_time   planned_expiration_time  loan_amount  \
# 0   657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00        125.0
# 1   657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00        400.0
# 2   658010 2014-01-09 08:00:00+00:00 2014-02-15 21:10:05+00:00        400.0
# 3   659347 2014-01-17 08:00:00+00:00 2014-02-21 03:10:02+00:00        625.0
# 4   656933 2013-12-17 08:00:00+00:00 2014-02-13 06:10:02+00:00        425.0
#
#    duration  disburse_year
# 0      53.0           2013
# 1      96.0           2013
# 2      37.0           2014
# 3      34.0           2014
# 4      57.0           2013

# %%
#Estrae il valore anno dalla data di fine prestito e pone a 0 gli anni che sono mancanti

ridotto['disburse_year'] = ridotto['disburse_year'].fillna(0)
ridotto['planned_expiration_year'] = ridotto['planned_expiration_time'].apply(lambda x: x.year).fillna(0).astype('Int64')
ridotto.head()
# Out:
#    loan_id             disburse_time   planned_expiration_time  loan_amount  \
# 0   657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00        125.0
# 1   657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00        400.0
# 2   658010 2014-01-09 08:00:00+00:00 2014-02-15 21:10:05+00:00        400.0
# 3   659347 2014-01-17 08:00:00+00:00 2014-02-21 03:10:02+00:00        625.0
# 4   656933 2013-12-17 08:00:00+00:00 2014-02-13 06:10:02+00:00        425.0
#
#    duration  disburse_year  planned_expiration_year
# 0      53.0           2013                     2014
# 1      96.0           2013                     2014
# 2      37.0           2014                     2014
# 3      34.0           2014                     2014
# 4      57.0           2013                     2014

# %%
#Creazione di un dizionario che associa ad ogni anno quanto è stato prestato.

#Nel caso in cui la durata del prestito sia sconosciuta:
#-se l'anno di fine è sconosciuto allora si associa l'intero ammontare del prestito all'anno di inizio dello stesso;
#-se l'anno di inizio è sconosciuto allora si associa l'intero ammonatare del prestito all'anno di fine dello stesso.

anni = {}
for row in range(len(ridotto)):
  if ridotto['duration'][row] <= 0 :
    if ridotto['planned_expiration_year'][row]== 0:
        anno = ridotto['disburse_year'][row]
        if anno not in anni:
          anni[anno] = ridotto['loan_amount'][row]
        else:
          anni[anno] += ridotto['loan_amount'][row]
        
    else:
        anno = ridotto['planned_expiration_year'][row]
        if anno not in anni:
          anni[anno] = ridotto['loan_amount'][row]
        else:
          anni[anno] += ridotto['loan_amount'][row]

  else:
    for i in range(int(ridotto['duration'][row]) + 1):
      giorno = ridotto['disburse_time'][row] + dt.timedelta(days = i)
      amount_per_day = ridotto['loan_amount'][row] / ridotto['duration'][row]
      if giorno.year not in anni: 
        anni[giorno.year] = amount_per_day 
      else:
        anni[giorno.year] += amount_per_day 

anni
# Out:
# {2013: 127881498.4674124,
#  2014: 157892334.19256365,
#  2015: 166338801.5925159,
#  2012: 116925768.89534897,
#  2016: 167644860.86099038,
#  2010: 72609150.0,
#  2017: 179764776.6890722,
#  2018: 6206379.696638751,
#  2009: 59689475.0,
#  2011: 91705613.02420591,
#  2007: 15446525.0,
#  2006: 1376575.0,
#  2008: 39423050.0,
#  2005: 102850.0,
#  0: 1525.0}

# %%
year_loans = pd.DataFrame(anni.items(), columns = ['Year', 'Amount']).sort_values(by = 'Year')
year_loans
# Out:
#     Year        Amount
# 14     0  1.525000e+03
# 13  2005  1.028500e+05
# 11  2006  1.376575e+06
# 10  2007  1.544652e+07
# 12  2008  3.942305e+07
# 8   2009  5.968948e+07
# 5   2010  7.260915e+07
# 9   2011  9.170561e+07
# 3   2012  1.169258e+08
# 0   2013  1.278815e+08
# 1   2014  1.578923e+08
# 2   2015  1.663388e+08
# 4   2016  1.676449e+08
# 6   2017  1.797648e+08
# 7   2018  6.206380e+06
